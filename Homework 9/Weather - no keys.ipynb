# %%
import requests

# %%
response = requests.post(
        "https://api.mailgun.net/v3/sandboxf739b30cd9aa47bf9fb818fc4c6883da.mailgun.org/messages",
        auth=("api", mailgun_key),
        data={"from": "Excited User <mailgun@sandbox69f4b1683cf340f1b876b47ae74e0d74.mailgun.org>",
              "to": "Excited User <mailgun@sandbox69f4b1683cf340f1b876b47ae74e0d74.mailgun.org>",
              "subject": "Hello",
              "text": "Testing some Mailgun awesomness!"})

response.text
# Out:
# '{\n  "id": "<20180619194733.1.4C1DD390FB8AF342@sandboxf739b30cd9aa47bf9fb818fc4c6883da.mailgun.org>",\n  "message": "Queued. Thank you."\n}'

# %%
response = requests.get('https://api.darksky.net/forecast/dark_sky_key/37.8267,-122.4233?units=si')
data = response.json()
print(data)
# Out:
# {'latitude': 37.8267, 'longitude': -122.4233, 'timezone': 'America/Los_Angeles', 'currently': {'time': 1529437654, 'summary': 'Partly Cloudy', 'icon': 'partly-cloudy-day', 'nearestStormDistance': 658, 'nearestStormBearing': 62, 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 16.69, 'apparentTemperature': 16.69, 'dewPoint': 12.11, 'humidity': 0.74, 'pressure': 1017.42, 'windSpeed': 2.79, 'windGust': 5.36, 'windBearing': 253, 'cloudCover': 0.29, 'uvIndex': 10, 'visibility': 16.09, 'ozone': 285.72}, 'minutely': {'summary': 'Partly cloudy for the hour.', 'icon': 'partly-cloudy-day', 'data': [{'time': 1529437620, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437680, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437740, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437800, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437860, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437920, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437980, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438040, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438100, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438160, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438220, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438280, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438340, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438400, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438460, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438520, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438580, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438640, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438700, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438760, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438820, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438880, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438940, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439000, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439060, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439120, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439180, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439240, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439300, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439360, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439420, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439480, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439540, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439600, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439660, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439720, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439780, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439840, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439900, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439960, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440020, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440080, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440140, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440200, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440260, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440320, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440380, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440440, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440500, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529440560, 'precipIntensity': 0, 'precipProbabilit ...

# %%
# Right now it is TEMPERATURE degrees out and SUMMARY. 
#Today will be TEMP_FEELING with a high of HIGH_TEMP and a low of LOW_TEMP. RAIN_WARNING.


response = requests.get('https://api.darksky.net/forecast/dark_sky_key/40.7128,-74.0060?units=si')
nyc = response.json()
print(nyc)
# Out:
# {'latitude': 40.7128, 'longitude': -74.006, 'timezone': 'America/New_York', 'currently': {'time': 1529437654, 'summary': 'Clear', 'icon': 'clear-day', 'nearestStormDistance': 111, 'nearestStormBearing': 197, 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 30.78, 'apparentTemperature': 30.78, 'dewPoint': 12.88, 'humidity': 0.34, 'pressure': 1008.45, 'windSpeed': 3.19, 'windGust': 3.77, 'windBearing': 340, 'cloudCover': 0.13, 'uvIndex': 5, 'visibility': 16.09, 'ozone': 302.24}, 'minutely': {'summary': 'Clear for the hour.', 'icon': 'clear-day', 'data': [{'time': 1529437620, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437680, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437740, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437800, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437860, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437920, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529437980, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438040, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438100, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438160, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438220, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438280, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438340, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438400, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438460, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438520, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438580, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438640, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438700, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438760, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529438820, 'precipIntensity': 0.0508, 'precipIntensityError': 0.0254, 'precipProbability': 0.01, 'precipType': 'rain'}, {'time': 1529438880, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.01, 'precipType': 'rain'}, {'time': 1529438940, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439000, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439060, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1529439120, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.01, 'precipType': 'rain'}, {'time': 1529439180, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.01, 'precipType': 'rain'}, {'time': 1529439240, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439300, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439360, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439420, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439480, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439540, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439600, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439660, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.02, 'precipType': 'rain'}, {'time': 1529439720, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.03, 'precipType': 'rain'}, {'time': 1529439780, 'precipIntensity': 0.0762, 'precipIntensityError': 0.0254, 'precipProbability': 0.03, 'precipType': 'rain'}, {'time': 1529439840, 'precipIntensity': 0.076 ...

# %%
nyc.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
current_temperature = nyc['currently']['temperature']
current_temperature
# Out:
# 30.78

# %%
summary = nyc['currently']['summary']
summary
# Out:
# 'Clear'

# %%
temp_feeling = nyc['currently']['temperature']

if temp_feeling > 25:
    print("hot")
elif temp_feeling < 15:
    print("cold")
else:
    print("warm")
# Out:
# hot

# %%
daily = nyc['daily']['data'][0]
    
print(daily['temperatureMax'])
# Out:
# 30.88

# %%
daily = nyc['daily']['data'][0]
    
print(daily['temperatureMin'])
# Out:
# 23.8

# %%
print(daily['precipProbability'])
# Out:
# 0.3

# %%
rain_warning = daily['precipProbability']

if rain_warning > 0.5:
    sentence = "Right now it is "+str(current_temperature)+" degrees out and "+summary+". Today will be "+str(temp_feeling)+" with a high of "+str(daily['temperatureMax'])+" and a low of "+str(daily['temperatureMin'])+" degrees. It's going to rain. Bring an umbrella!"

else:
    sentence = "Right now it is "+str(current_temperature)+" degrees out and "+summary+". Today will be "+str(temp_feeling)+" with a high of "+str(daily['temperatureMax'])+" and a low of "+str(daily['temperatureMin'])+" degrees. It's not going to rain. You don't need an umbrella!"
    
print(sentence)
# Out:
# Right now it is 30.78 degrees out and Clear. Today will be 30.78 with a high of 30.88 and a low of 23.8 degrees. It's not going to rain. You don't need an umbrella!

# %%
import datetime
right_now = datetime.datetime.now()
right_now

response = requests.post(
        "https://api.mailgun.net/v3/sandboxf739b30cd9aa47bf9fb818fc4c6883da.mailgun.org/messages",
        auth=("api", mailgun_key),
        data={"from": "Excited User <mailgun@sandbox69f4b1683cf340f1b876b47ae74e0d74.mailgun.org>",
              "to": "Excited User <mailgun@sandbox69f4b1683cf340f1b876b47ae74e0d74.mailgun.org>",
              "subject": "8AM Weather forecast: "+ str(right_now.strftime("%Y-%m-%d")),
              "text": sentence})
