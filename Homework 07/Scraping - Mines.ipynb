# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()

driver.get("https://arlweb.msha.gov/drs/drshome.htm")

# %%
text_input = driver.find_element_by_name('OperSearch')

# %%
driver.execute_script("arguments[0].scrollIntoView(true)", text_input)

# %%
text_input.send_keys('dirt')

# %%
abandoned_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[3]/td[3]/table/tbody/tr/td/input')
abandoned_button.click()

# %%
button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
driver.find_elements_by_tag_name('tr')[7].text
# Out:
# '3503598\nOR  Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC '

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
operators = driver.find_elements_by_tag_name('tr')
for operator in operators [7:]:
        columns = operator.find_elements_by_tag_name('td')[2]
        print(columns.text)
# Out:
# Newberg Rock & Dirt
# Allied Dirt Moving Company
# AM Dirtworks & Aggregate Sales
# Atlas-Dirty Devil Mining
# Atlas-Dirty Devil Mining
# Babe's Dirt Work
# Bar-Lin Dirt Company
# Barber'S Dirt Pit
# Bender Sand & Dirt
# BERT'S DIRT
# Big D Dirt Service Inc
# Big Red Dirt Farm LLC
# Big River Dirt Pit
# Bob Harris Dirt Contracting
# Bohannon Sand & Dirt
# Bratcher'S Sand & Dirt
# Brewer Dirt Works
# Buck'S Dirt Pit
# C & G Dirt Hauling
# C N C Dirt Movers, Inc.
# Cambridge Dirt Sand and Gravel LLC
# Central Iowa Dirt & Demo LLC
# Crowes Trucking & Dirt Pit Services
# D & H Dirt
# Diez Dirt & Sand Hauling Inc
# Dirt Cheap
# Dirt Company
# Dirt Company
# Dirt Company
# Dirt Con
# Dirt Diggers Inc
# Dirt Doctor Inc
# Dirt Inc
# Dirt Pit
# Dirt Work Specialists LLC
# Dirt Works
# Dirtco Inc
# Dirtman Trucking
# DIRTWORKS, INC.
# Dirtworks, Inc.
# Dirty Coal
# Dorchester Dirt Company Inc
# Douglas Dirt Sand & Gravel Company
# Ell Dirt Works LLC.
# Floyd Smith Dirt Pit
# Gary Kelm Dirt Service
# Gerald Fenger/Rock & Dirt Const
# Gerald Illies Gravel & Dirt Company
# Guidry Sand & Dirt Pit Inc
# Harris Dirt Company Inc
# Hatchet Creek Rock & Dirt LLC
# Holley Dirt Company, Inc
# Iske Dirt Sand & Gravel
# J M Lynn Dirtwork
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jake Diel Dirt & Paving Inc
# Jarratt Dirt Work and Paving, Inc.
# JBS DIRT, INC.
# Jones Bros Dirt & Paving Contractors Inc
# Krueger Brothers Gravel & Dirt
# Krueger Dirt Werx, Inc.
# L I P Dirt & Trucking
# Lee'S Dirt Pit Inc
# Little-G-Dirt Pit
# Lone Star Dirt & Paving
# Loyd'S Dirt & Gravel
# M R Dirt
# M.C. Dirt LLC
# M.R. Dirt Inc.
# Maurice Dirt & Sand
# Mc Dirt Industries Inc
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Mike Duhon Dirt Pit
# Moss Dirt Company
# Moss Dirt Company
# Muckler Fill Dirt & Top Soil
# Nelson & Sons Dirt Haulers Inc
# Nelson'S Dirt Pit
# Nicholson Dirt Contracting
# Nitty Gritty Dirt LLC
# Northest Louisiana Dirt Contractors
# Orvil Carter Dirt Contractor Inc
# Orvil Carter Dirt Contractor Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc
# P B Dirt Movers Inc.
# P B Dirt Movers, Inc
# P B Dirt Movers, Inc.
# P.B. Dirtmovers
# PAPA'S DIRT WORKES
# Paydirt Exc Inc
# PB Dirt Movers
# PB Dirt Movers Inc.
# PB Dirt Movers, Inc
# Peveto Dirt Pit
# Phil-Dirt Industries, Inc
# Prescott Dirt, LLC
# R & R Dirtworks
# R D Blankenship Dirt Work LLC
# Reeves Dirt Pit Inc
# River Bottom Dirt
# Roe'S Dirt Pit
# Russell Trest-Dirt Contractor
# S J Stahr Dirt Movers Inc
# Sand & Dirt, Inc
# Sand and Dirt, Inc.
# Sierra Rock & Dirt, Inc.
# Simpson Dirtworx llc
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Slay'S Dirt Hauling
# Southside Dirt Company
# Spry's Dirt & Gravel, Inc.
# Stewart Dirt Pit
# Stewart Dirt Work, Inc.
# Sweat'S Dirt Hauling Inc
# Toler Roe Dirt Pit
# Tres Palacios Dirt, Sand & Gravel
# Vogt Dirt Service
# Watson Dirt Sand & Gravel Pit Inc
# Y B Dirt & Loam
# Yarbrough Dirt Pit Inc
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-31ec048699ac> in <module>()
#       1 operators = driver.find_elements_by_tag_name('tr')
#       2 for operator in operators [7:]:
# ----> 3         columns = operator.find_elements_by_tag_name('td')[2]
#       4         print(columns.text)
#
# IndexError: list index out of range

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
operators = driver.find_elements_by_tag_name('tr')
for operator in operators [7:]:
        operator_id = operator.find_elements_by_tag_name('td')[0]
        print(operator_id.text)

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
operators = driver.find_elements_by_tag_name('tr')[7:]

# %%
mines = []

# %%
for operator in operators:
    print('-----------')
    row = {}

    ID = operator.find_elements_by_tag_name('td')[0]
    row['ID'] = ID.text
    
    State = operator.find_elements_by_tag_name('td')[1]
    row['State'] = State.text
    
    Operator_Name = operator.find_elements_by_tag_name('td')[2]
    row['Operator_Name'] = Operator_Name.text
    
    Mine_Name = operator.find_elements_by_tag_name('td')[3]
    row['Mine_Name'] = Mine_Name.text
    
    Type = operator.find_elements_by_tag_name('td')[4]
    row['Type'] = Type.text
    
    CM = operator.find_elements_by_tag_name('td')[5]
    row['CM'] = CM.text
    
    Status = operator.find_elements_by_tag_name('td')[6]
    row['Status'] = Status.text
    
    Commodity = operator.find_elements_by_tag_name('td')[7]
    row['Commodity'] = Commodity.text
    
    print("dictionary look like", row)
    
    mines.append(row)
# Out:
# -----------
# dictionary look like {'ID': '3503598', 'State': 'OR ', 'Operator_Name': 'Newberg Rock & Dirt  ', 'Mine_Name': 'Newberg Rock & Dirt', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}
# -----------
# dictionary look like {'ID': '0502030', 'State': 'CO ', 'Operator_Name': 'Allied Dirt Moving Company  ', 'Mine_Name': 'Allied Dirt Moving Co Pit & Plant', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4801789', 'State': 'ND ', 'Operator_Name': 'AM Dirtworks & Aggregate Sales  ', 'Mine_Name': 'AM Dirtworks & Aggregate Sales', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4201449', 'State': 'UT ', 'Operator_Name': 'Atlas-Dirty Devil Mining  ', 'Mine_Name': 'Unit Train Loading Facility', 'Type': 'Facility', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '4201450', 'State': 'UT ', 'Operator_Name': 'Atlas-Dirty Devil Mining  ', 'Mine_Name': 'Blackie Surface Mine & Prep Plant', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '1002257', 'State': 'ID ', 'Operator_Name': "Babe's Dirt Work  ", 'Mine_Name': 'Hitt Pit, Inc.', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601167', 'State': 'LA ', 'Operator_Name': 'Bar-Lin Dirt Company  ', 'Mine_Name': 'Bar-Lin Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4103265', 'State': 'TX ', 'Operator_Name': "Barber'S Dirt Pit  ", 'Mine_Name': "Barber'S Dirt Pit", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1401575', 'State': 'KS ', 'Operator_Name': 'Bender Sand & Dirt  ', 'Mine_Name': 'BENDER SAND & DIRT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1700776', 'State': 'ME ', 'Operator_Name': "BERT'S DIRT  ", 'Mine_Name': "BERT'S DIRT", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601251', 'State': 'LA ', 'Operator_Name': 'Big D Dirt Service Inc  ', 'Mine_Name': 'Dorothy V Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0301963', 'State': 'AR ', 'Operator_Name': 'Big Red Dirt Farm LLC  ', 'Mine_Name': 'Big Red Dirt Farm', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601082', 'State': 'LA ', 'Operator_Name': 'Big River Dirt Pit  ', 'Mine_Name': 'Big River Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3401751', 'State': 'OK ', 'Operator_Name': 'Bob Harris Dirt Contracting  ', 'Mine_Name': 'Harris Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1600916', 'State': 'LA ', 'Operator_Name': 'Bohannon Sand & Dirt  ', 'Mine_Name': 'BOHANNON SAND & DIRT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3401211', 'State': 'OK ', 'Operator_Name': "Bratcher'S Sand & Dirt  ", 'Mine_Name': 'Eubanks Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0301267', 'State': 'AR ', 'Operator_Name': 'Brewer Dirt Works  ', 'Mine_Name': 'Brewer Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1600956', 'State': 'LA ', 'Operator_Name': "Buck'S Dirt Pit  ", 'Mine_Name': "Buck'S Dirt Pit", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2200033', 'State': 'MS ', 'Operator_Name': 'C & G Dirt Hauling  ', 'Mine_Name': 'Laurel Brick & Tile', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Common Clays NEC '}
# -----------
# dictionary look like {'ID': '0504953', 'State': 'NM ', 'Operator_Name': 'C N C Dirt Movers, Inc.  ', 'Mine_Name': 'Foster Canyon', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3401929', 'State': 'OK ', 'Operator_Name': 'Cambridge Dirt Sand and Gravel LLC  ', 'Mine_Name': 'Cambridge #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Sand, Industrial NEC '}
# -----------
# dictionary look like {'ID': '1302445', 'State': 'IA ', 'Operator_Name': 'Central Iowa Dirt & Demo LLC  ', 'Mine_Name': 'Woolstock', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601106', 'State': 'LA ', 'Operator_Name': 'Crowes Trucking & Dirt Pit Services  ', 'Mine_Name': 'Crowes Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3400915', 'State': 'OK ', 'Operator_Name': 'D & H Dirt  ', 'Mine_Name': 'D & H Dirt', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1600983', 'State': 'LA ', 'Operator_Name': 'Diez Dirt & Sand Hauling Inc  ', 'Mine_Name': 'Amite Acres Dredge', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4503200', 'State': 'WA ', 'Operator_Name': 'Dirt Cheap  ', 'Mine_Name': 'Dirt Cheap', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Common Clays NEC '}
# -----------
# dictionary look like {'ID': '3401266', 'State': 'OK ', 'Operator_Name': 'Dirt Company  ', 'Mine_Name': 'Pit #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3401468', 'State': 'OK ', 'Operator_Name': 'Dirt Company  ', 'Mine_Name': 'Hicks Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '5001797', 'State': 'AK ', 'Operator_Name': 'Dirt Company  ', 'Mine_Name': 'Bush Pilot', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4608254', 'State': 'WV ', 'Operator_Name': 'Dirt Con  ', 'Mine_Name': 'Hog Lick Quarry', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '1510279', 'State': 'KY ', 'Operator_Name': 'Dirt Diggers Inc  ', 'Mine_Name': 'Debco Mine', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '2103723', 'State': 'MN ', 'Operator_Name': 'Dirt Doctor Inc  ', 'Mine_Name': 'Rock Lake Plant', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0100776', 'State': 'AL ', 'Operator_Name': 'Dirt Inc  ', 'Mine_Name': 'Harrison Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Common Clays NEC '}
# -----------
# dictionary look like {'ID': '4104016', 'State': 'TX ', 'Operator_Name': 'Dirt Pit  ', 'Mine_Name': 'THE DIRT PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2103914', 'State': 'MN ', 'Operator_Name': 'Dirt Work Specialists LLC  ', 'Mine_Name': 'Astec Plant', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4104757', 'State': 'TX ', 'Operator_Name': 'Dirt Works  ', 'Mine_Name': 'Portable #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0301729', 'State': 'AR ', 'Operator_Name': 'Dirtco Inc  ', 'Mine_Name': 'DIRTCO INC', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0404851', 'State': 'CA ', 'Operator_Name': 'Dirtman Trucking  ', 'Mine_Name': 'Dirtman Sand & Gravel #2', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2200734', 'State': 'MS ', 'Operator_Name': 'DIRTWORKS, INC.  ', 'Mine_Name': 'DIRTWORKS, INC.', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '5002028', 'State': 'AK ', 'Operator_Name': 'Dirtworks, Inc.  ', 'Mine_Name': 'Dirtworks, Inc.', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1513393', 'State': 'KY ', 'Operator_Name': 'Dirty Coal  ', 'Mine_Name': 'No 1 Surface', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '3800602', 'State': 'SC ', 'Operator_Name': 'Dorchester Dirt Company Inc  ', 'Mine_Name': 'DIAMOND MINE #3', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3101630', 'State': 'NC ', 'Operator_Name': 'Douglas Dirt Sand & Gravel Company  ', 'Mine_Name': 'Mccormick Pit & Plant', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Granite '}
# -----------
# dictionary look like {'ID': '3200860', 'State': 'ND ', 'Operator_Name': 'Ell Dirt Works LLC.  ', 'Mine_Name': 'Portable Jaw #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3401762', 'State': 'OK ', 'Operator_Name': 'Floyd Smith Dirt Pit  ', 'Mine_Name': 'Floyd Smith Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Dimension Stone NEC '}
# -----------
# dictionary look like {'ID': '2103517', 'State': 'MN ', 'Operator_Name': 'Gary Kelm Dirt Service  ', 'Mine_Name': 'Screener', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2402626', 'State': 'MT ', 'Operator_Name': 'Gerald Fenger/Rock & Dirt Const  ', 'Mine_Name': 'Aden Ward', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2103181', 'State': 'MN ', 'Operator_Name': 'Gerald Illies Gravel & Dirt Company  ', 'Mine_Name': 'PORTABLE CRUSHER', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601124', 'State': 'LA ', 'Operator_Name': 'Guidry Sand & Dirt Pit Inc  ', 'Mine_Name': 'Guidry Sand & Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601150', 'State': 'LA ', 'Operator_Name': 'Harris Dirt Company Inc  ', 'Mine_Name': 'Harris Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4703427', 'State': 'WI ', 'Operator_Name': 'Hatchet Creek Rock & Dirt LLC  ', 'Mine_Name': 'Hatchet Creek Rock & Dirt LLC', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0801306', 'State': 'FL ', 'Operator_Name': 'Holley Dirt Company, Inc  ', 'Mine_Name': 'River Road Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}
# -----------
# dictionary look like {'ID': '2501216', 'State': 'NE ', 'Operator_Name': 'Iske Dirt Sand & Gravel  ', 'Mine_Name': 'Iske Dirt Sand & Gravel', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3200965', 'State': 'ND ', 'Operator_Name': 'J M Lynn Dirtwork  ', 'Mine_Name': 'Johnson Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2901371', 'State': 'NM ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Diel Screening Plant', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2901544', 'State': 'NM ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Cortez Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2901709', 'State': 'NM ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Skaggs Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Stone NEC '}
# -----------
# dictionary look like {'ID': '4102355', 'State': 'TX ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Jacobson Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '4102420', 'State': 'TX ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Black Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '4102869', 'State': 'TX ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Bailey Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Stone NEC '}
# -----------
# dictionary look like {'ID': '4102951', 'State': 'TX ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Toscosa Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '4102958', 'State': 'TX ', 'Operator_Name': 'Jake Diel Dirt & Paving Inc  ', 'Mine_Name': 'Four Way Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4104876', 'State': 'TX ', 'Operator_Name': 'Jarratt Dirt Work and Paving, Inc.  ', 'Mine_Name': 'Portable Screening Plant #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Stone NEC '}
# -----------
# dictionary look like {'ID': '3003502', 'State': 'NY ', 'Operator_Name': 'JBS DIRT, INC.  ', 'Mine_Name': 'SHAMROCK PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4103258', 'State': 'TX ', 'Operator_Name': 'Jones Bros Dirt & Paving Contractors Inc  ', 'Mine_Name': 'Barstow Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '3901432', 'State': 'SD ', 'Operator_Name': 'Krueger Brothers Gravel & Dirt  ', 'Mine_Name': 'PORTABLE SCREENER', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2103556', 'State': 'MN ', 'Operator_Name': 'Krueger Dirt Werx, Inc.  ', 'Mine_Name': 'Krueger Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601250', 'State': 'LA ', 'Operator_Name': 'L I P Dirt & Trucking  ', 'Mine_Name': 'L I P Dirt & Trucking', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1600908', 'State': 'LA ', 'Operator_Name': "Lee'S Dirt Pit Inc  ", 'Mine_Name': "Lee'S Dirt Pit", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1600953', 'State': 'LA ', 'Operator_Name': 'Little-G-Dirt Pit  ', 'Mine_Name': 'Little-G-Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4104185', 'State': 'TX ', 'Operator_Name': 'Lone Star Dirt & Paving  ', 'Mine_Name': 'Lone Star Crusher', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Stone NEC '}
# -----------
# dictionary look like {'ID': '2901536', 'State': 'NM ', 'Operator_Name': "Loyd'S Dirt & Gravel  ", 'Mine_Name': "LOYD'S PIT", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3609624', 'State': 'PA ', 'Operator_Name': 'M R Dirt  ', 'Mine_Name': 'Forbes Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Temporarily Idled ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3800709', 'State': 'SC ', 'Operator_Name': 'M.C. Dirt LLC  ', 'Mine_Name': 'Middleton Site', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Sand, Common '}
# -----------
# dictionary look like {'ID': '3609931', 'State': 'PA ', 'Operator_Name': 'M.R. Dirt Inc.  ', 'Mine_Name': 'Camptown Quarry', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Dimension Stone NEC '}
# -----------
# dictionary look like {'ID': '1601257', 'State': 'LA ', 'Operator_Name': 'Maurice Dirt & Sand  ', 'Mine_Name': 'Maurice Dirt And Sand', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0801275', 'State': 'FL ', 'Operator_Name': 'Mc Dirt Industries Inc  ', 'Mine_Name': 'BELLVIEW', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601379', 'State': 'LA ', 'Operator_Name': 'Mike Duhon Dirt Pit  ', 'Mine_Name': 'REDS PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601380', 'State': 'LA ', 'Operator_Name': 'Mike Duhon Dirt Pit  ', 'Mine_Name': 'WAINWRIGHT PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601381', 'State': 'LA ', 'Operator_Name': 'Mike Duhon Dirt Pit  ', 'Mine_Name': 'COX PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601134', 'State': 'LA ', 'Operator_Name': 'Moss Dirt Company  ', 'Mine_Name': 'Cook Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601165', 'State': 'LA ', 'Operator_Name': 'Moss Dirt Company  ', 'Mine_Name': 'Moss Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '3901042', 'State': 'SD ', 'Operator_Name': 'Muckler Fill Dirt & Top Soil  ', 'Mine_Name': 'Hoffman Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601194', 'State': 'LA ', 'Operator_Name': 'Nelson & Sons Dirt Haulers Inc  ', 'Mine_Name': 'Nelson & Sons Dirt Haulers Incorporated', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4104054', 'State': 'TX ', 'Operator_Name': "Nelson'S Dirt Pit  ", 'Mine_Name': "NELSON'S DIRT PIT", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4801674', 'State': 'WY ', 'Operator_Name': 'Nicholson Dirt Contracting  ', 'Mine_Name': 'Eagle One', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2402474', 'State': 'MT ', 'Operator_Name': 'Nitty Gritty Dirt LLC  ', 'Mine_Name': 'Rolling Glen Ranch Sand and Gravel', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1600920', 'State': 'LA ', 'Operator_Name': 'Northest Louisiana Dirt Contractors  ', 'Mine_Name': 'Calhoun And Mcguire Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4102955', 'State': 'TX ', 'Operator_Name': 'Orvil Carter Dirt Contractor Inc  ', 'Mine_Name': 'Ed Meek Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '4103107', 'State': 'TX ', 'Operator_Name': 'Orvil Carter Dirt Contractor Inc  ', 'Mine_Name': 'Seitz Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '1512530', 'State': 'KY ', 'Operator_Name': 'P B Dirt Movers Inc  ', 'Mine_Name': 'No 1 Surface', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '1515619', 'State': 'KY ', 'Operator_Name': 'P B Dirt Movers Inc  ', 'Mine_Name': 'No 5 Surface', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '1518318', 'State': 'KY ', 'Operator_Name': 'P B Dirt Movers Inc  ', 'Mine_Name': 'Biggs No 1', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '4405366', 'State': 'VA ', 'Operator_Name': 'P B Dirt Movers Inc  ', 'Mine_Name': 'No 1 Strip', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '4407196', 'State': 'VA ', 'Operator_Name': 'P B Dirt Movers Inc  ', 'Mine_Name': 'No 2', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '1519685', 'State': 'KY ', 'Operator_Name': 'P B Dirt Movers Inc.  ', 'Mine_Name': 'Fedscreek Refuse Pile', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '1519799', 'State': 'KY ', 'Operator_Name': 'P B Dirt Movers, Inc  ', 'Mine_Name': 'Fedscreek Surface', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Active ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '4407379', 'State': 'VA ', 'Operator_Name': 'P B Dirt Movers, Inc.  ', 'Mine_Name': 'No. 3', 'Type': 'Surface', 'CM': 'C ', 'Status': 'New Mine ', 'Commodity': ' '}
# -----------
# dictionary look like {'ID': '4407003', 'State': 'VA ', 'Operator_Name': 'P.B. Dirtmovers  ', 'Mine_Name': 'No 2', 'Type': 'Underground', 'CM': 'C ', 'Status': 'Abandoned* ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '2602570', 'State': 'NV ', 'Operator_Name': "PAPA'S DIRT WORKES  ", 'Mine_Name': 'COUNTY FAIRE TEMP GRAVEL PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2402503', 'State': 'MT ', 'Operator_Name': 'Paydirt Exc Inc  ', 'Mine_Name': 'Robison Mine', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4407296', 'State': 'VA ', 'Operator_Name': 'PB Dirt Movers  ', 'Mine_Name': 'Mine No. 6', 'Type': 'Underground', 'CM': 'C ', 'Status': 'Temporarily Idled ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '1519273', 'State': 'KY ', 'Operator_Name': 'PB Dirt Movers Inc.  ', 'Mine_Name': 'Blair Face Up', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '4407270', 'State': 'VA ', 'Operator_Name': 'PB Dirt Movers, Inc  ', 'Mine_Name': 'Surface Mine No. 1', 'Type': 'Surface', 'CM': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}
# -----------
# dictionary look like {'ID': '4102682', 'State': 'TX ', 'Operator_Name': 'Peveto Dirt Pit  ', 'Mine_Name': 'Peveto Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0801259', 'State': 'FL ', 'Operator_Name': 'Phil-Dirt Industries, Inc  ', 'Mine_Name': 'PIT #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0203332', 'State': 'AZ ', 'Operator_Name': 'Prescott Dirt, LLC  ', 'Mine_Name': 'Sandretto Drive', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0302015', 'State': 'AR ', 'Operator_Name': 'R & R Dirtworks  ', 'Mine_Name': 'Martins Quarry', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Limestone NEC '}
# -----------
# dictionary look like {'ID': '2901986', 'State': 'NM ', 'Operator_Name': 'R D Blankenship Dirt Work LLC  ', 'Mine_Name': 'R D BLANKENSHIP DIRT WORK', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Active ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601127', 'State': 'LA ', 'Operator_Name': 'Reeves Dirt Pit Inc  ', 'Mine_Name': 'Reeves Dirt Pit Incorporated', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4105017', 'State': 'TX ', 'Operator_Name': 'River Bottom Dirt  ', 'Mine_Name': 'River Bottom Dirt', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Sand, Common '}
# -----------
# dictionary look like {'ID': '1600986', 'State': 'LA ', 'Operator_Name': "Roe'S Dirt Pit  ", 'Mine_Name': "Roe'S Dirt Pit", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4103324', 'State': 'TX ', 'Operator_Name': 'Russell Trest-Dirt Contractor  ', 'Mine_Name': 'Pine Ridge Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4202013', 'State': 'UT ', 'Operator_Name': 'S J Stahr Dirt Movers Inc  ', 'Mine_Name': 'Stahr Portable Crusher', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0801417', 'State': 'FL ', 'Operator_Name': 'Sand & Dirt, Inc  ', 'Mine_Name': 'Molino Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Active ', 'Commodity': 'Sand, Common '}
# -----------
# dictionary look like {'ID': '0801371', 'State': 'FL ', 'Operator_Name': 'Sand and Dirt, Inc.  ', 'Mine_Name': 'CENTURY PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Sand, Common '}
# -----------
# dictionary look like {'ID': '2402115', 'State': 'MT ', 'Operator_Name': 'Sierra Rock & Dirt, Inc.  ', 'Mine_Name': 'Sierra Rock & Dirt Inc', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4300748', 'State': 'VT ', 'Operator_Name': 'Simpson Dirtworx llc  ', 'Mine_Name': 'Simpson Sand and Gravel', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4300768', 'State': 'VT ', 'Operator_Name': 'SIMPSON DIRTWORX LLC  ', 'Mine_Name': 'Pettibone Jaw Crusher', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4300776', 'State': 'VT ', 'Operator_Name': 'SIMPSON DIRTWORX LLC  ', 'Mine_Name': 'Chieftan 1400', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '0103209', 'State': 'AL ', 'Operator_Name': "Slay'S Dirt Hauling  ", 'Mine_Name': 'SLAY PIT', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601159', 'State': 'LA ', 'Operator_Name': 'Southside Dirt Company  ', 'Mine_Name': 'Southside Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2302283', 'State': 'MO ', 'Operator_Name': "Spry's Dirt & Gravel, Inc.  ", 'Mine_Name': "Mike's Money Pit", 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4102586', 'State': 'TX ', 'Operator_Name': 'Stewart Dirt Pit  ', 'Mine_Name': 'Stewart Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4104475', 'State': 'TX ', 'Operator_Name': 'Stewart Dirt Work, Inc.  ', 'Mine_Name': 'Stewart Dirt Work Inc - Hanna Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Crushed, Broken Stone NEC '}
# -----------
# dictionary look like {'ID': '3800617', 'State': 'SC ', 'Operator_Name': "Sweat'S Dirt Hauling Inc  ", 'Mine_Name': 'Highway 642 Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601234', 'State': 'LA ', 'Operator_Name': 'Toler Roe Dirt Pit  ', 'Mine_Name': 'Toler Roe Dirt Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4104648', 'State': 'TX ', 'Operator_Name': 'Tres Palacios Dirt, Sand & Gravel  ', 'Mine_Name': 'La Calichera Pit', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '2103518', 'State': 'MN ', 'Operator_Name': 'Vogt Dirt Service  ', 'Mine_Name': 'Crusher', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '1601292', 'State': 'LA ', 'Operator_Name': 'Watson Dirt Sand & Gravel Pit Inc  ', 'Mine_Name': 'ADDISON LEASE', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4103429', 'State': 'TX ', 'Operator_Name': 'Y B Dirt & Loam  ', 'Mine_Name': 'Y B Mine', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# dictionary look like {'ID': '4103264', 'State': 'TX ', 'Operator_Name': 'Yarbrough Dirt Pit Inc  ', 'Mine_Name': 'Yarbrough Dirt Pit #1', 'Type': 'Surface', 'CM': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}
# -----------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-fc36701c1ece> in <module>()
#       6     row['ID'] = ID.text
#       7
# ----> 8     State = operator.find_elements_by_tag_name('td')[1]
#       9     row['State'] = State.text
#      10
#
# IndexError: list index out of range

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
import pandas as pd

# %%
df = pd.DataFrame(mines)
df.head(10)
# Out:
#    CM                      Commodity       ID  \
# 0  M      Crushed, Broken Stone NEC   3503598
# 1  M   Construction Sand and Gravel   0502030
# 2  M   Construction Sand and Gravel   4801789
# 3  C              Coal (Bituminous)   4201449
# 4  C              Coal (Bituminous)   4201450
# 5  M   Construction Sand and Gravel   1002257
# 6  M   Construction Sand and Gravel   1601167
# 7  M   Construction Sand and Gravel   4103265
# 8  M   Construction Sand and Gravel   1401575
# 9  M   Construction Sand and Gravel   1700776
#
#                            Mine_Name                     Operator_Name State  \
# 0                Newberg Rock & Dirt             Newberg Rock & Dirt     OR
# 1  Allied Dirt Moving Co Pit & Plant      Allied Dirt Moving Company     CO
# 2     AM Dirtworks & Aggregate Sales  AM Dirtworks & Aggregate Sales     ND
# 3        Unit Train Loading Facility        Atlas-Dirty Devil Mining     UT
# 4  Blackie Surface Mine & Prep Plant        Atlas-Dirty Devil Mining     UT
# 5                     Hitt Pit, Inc.                Babe's Dirt Work     ID
# 6                   Bar-Lin Dirt Pit            Bar-Lin Dirt Company     LA
# 7                  Barber'S Dirt Pit               Barber'S Dirt Pit     TX
# 8                 BENDER SAND & DIRT              Bender Sand & Dirt     KS
# 9                        BERT'S DIRT                     BERT'S DIRT     ME
#
#           Status      Type
# 0        Active    Surface
# 1     Abandoned    Surface
# 2     Abandoned    Surface
# 3     Abandoned   Facility
# 4     Abandoned    Surface
# 5     Abandoned    Surface
# 6     Abandoned    Surface
# 7     Abandoned    Surface
# 8  Intermittent    Surface
# 9     Abandoned    Surface

# %%
df.to_csv("dirt-operators.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
df = pd.read_csv('dirt-operators.csv')
df
# Out:
#      CM                       Commodity       ID  \
# 0    M       Crushed, Broken Stone NEC   3503598
# 1    M    Construction Sand and Gravel    502030
# 2    M    Construction Sand and Gravel   4801789
# 3    C               Coal (Bituminous)   4201449
# 4    C               Coal (Bituminous)   4201450
# 5    M    Construction Sand and Gravel   1002257
# 6    M    Construction Sand and Gravel   1601167
# 7    M    Construction Sand and Gravel   4103265
# 8    M    Construction Sand and Gravel   1401575
# 9    M    Construction Sand and Gravel   1700776
# 10   M    Construction Sand and Gravel   1601251
# 11   M    Construction Sand and Gravel    301963
# 12   M    Construction Sand and Gravel   1601082
# 13   M    Construction Sand and Gravel   3401751
# 14   M    Construction Sand and Gravel   1600916
# 15   M    Construction Sand and Gravel   3401211
# 16   M    Construction Sand and Gravel    301267
# 17   M    Construction Sand and Gravel   1600956
# 18   M                Common Clays NEC   2200033
# 19   M    Construction Sand and Gravel    504953
# 20   M            Sand, Industrial NEC   3401929
# 21   M    Construction Sand and Gravel   1302445
# 22   M    Construction Sand and Gravel   1601106
# 23   M    Construction Sand and Gravel   3400915
# 24   M    Construction Sand and Gravel   1600983
# 25   M                Common Clays NEC   4503200
# 26   M    Construction Sand and Gravel   3401266
# 27   M    Construction Sand and Gravel   3401468
# 28   M    Construction Sand and Gravel   5001797
# 29   M   Crushed, Broken Limestone NEC   4608254
# ..   ..                             ...      ...
# 234  C               Coal (Bituminous)   1519273
# 235  C               Coal (Bituminous)   4407270
# 236  M    Construction Sand and Gravel   4102682
# 237  M    Construction Sand and Gravel    801259
# 238  M    Construction Sand and Gravel    203332
# 239  M   Crushed, Broken Limestone NEC    302015
# 240  M    Construction Sand and Gravel   2901986
# 241  M    Construction Sand and Gravel   1601127
# 242  M                    Sand, Common   4105017
# 243  M    Construction Sand and Gravel   1600986
# 244  M    Construction Sand and Gravel   4103324
# 245  M    Construction Sand and Gravel   4202013
# 246  M                    Sand, Common    801417
# 247  M                    Sand, Common    801371
# 248  M    Construction Sand and Gravel   2402115
# 249  M    Construction Sand and Gravel   4300748
# 250  M    Construction Sand and Gravel   4300768
# 251  M    Construction Sand and Gravel   4300776
# 252  M    Construction Sand and Gravel    103209
# 253  M    Construction Sand and Gravel   1601159
# 254  M    Construction Sand and Gravel   2302283
# 255  M    Construction Sand and Gravel   4102586
# 256  M       Crushed, Broken Stone NEC   4104475
# 257  M    Construction Sand and Gravel   3800617
# 258  M    Construction Sand and Gravel   1601234
# 259  M    Construction Sand and Gravel   4104648
# 260  M    Construction Sand and Gravel   2103518
# 261  M    Construction Sand and Gravel   1601292
# 262  M    Construction Sand and Gravel   4103429
# 263  M    Construction Sand and Gravel   4103264
#
#                              Mine_Name                          Operator_Name  \
# 0                  Newberg Rock & Dirt                  Newberg Rock & Dirt
# 1    Allied Dirt Moving Co Pit & Plant           Allied Dirt Moving Company
# 2       AM Dirtworks & Aggregate Sales       AM Dirtworks & Aggregate Sales
# 3          Unit Train Loading Facility             Atlas-Dirty Devil Mining
# 4    Blackie Surface Mine & Prep Plant             Atlas-Dirty Devil Mining
# 5                       Hitt Pit, Inc.                     Babe's Dirt Work
# 6                     Bar-Lin Dirt Pit                 Bar-Lin Dirt Company
# 7                    Barber'S Dirt Pit                    Barber'S Dirt Pit
# 8                   BENDER SAND & DIRT                   Bender Sand & Dirt
# 9                          BERT'S DIRT                          BERT'S DIRT
# 10                       Dorothy V Pit               Big D Dirt Service Inc
# 11                   Big Red Dirt Farm                Big Red Dirt Farm LLC
# 12                  Big River Dirt Pit                   Big River Dirt Pit
# 13                          Harris Pit          Bob Harris Dirt Contracting
# 14                BOHANNON SAND & DIRT                 Bohannon Sand & Dirt
# 15                         Eubanks Pit               Bratcher'S Sand & Dirt
# 16                          Brewer Pit                    Brewer Dirt Works
# 17                     Buck'S Dirt Pit                      Buck'S Dirt Pit
# 18                 Laurel Brick & Tile                   C & G Dirt Hauling
# 19                       Foster Canyon              C N C Dirt Movers, Inc.
# 20                        Cambridge #1   Cambridge Dirt Sand and Gravel LLC
# 21                           Woolstock         Central Iowa Dirt & Demo LLC
# 22                     Crowes Dirt Pit  Crowes Trucking & Dirt Pit Services
# 23                          D & H Dirt                           D & H Dirt
# 24                  Amite Acres Dredge         Diez Dirt & Sand Hauling Inc
# 25                          Dirt Cheap                           Dirt Cheap
# 26                              Pit #1                         Dirt Company
# 27                           Hicks Pit                         Dirt Company
# 28                          Bush Pilot                         Dirt Company
# 29                     Hog Lick Quarry                             Dirt Con
# ..                                 ...                                    ...
# 234                      Blair Face Up                  PB Dirt Movers Inc.
# 235                 Surface Mine No. 1                  PB Dirt Movers, Inc
# 236                         Peveto Pit                      Peveto Dirt Pit
# 237                             PIT #1            Phil-Dirt Industries, Inc
# 238                    Sandretto Drive                   Prescott Dirt, LLC
# 239                     Martins Quarry                      R & R Dirtworks
# 240          R D BLANKENSHIP DIRT WORK        R D Blankenship Dirt Work LLC
# 241       Reeves Dirt Pit Incorporated                  Reeves Dirt Pit Inc
# 242                  River Bottom Dirt                    River Bottom Dirt
# 243                     Roe'S Dirt Pit                       Roe'S Dirt Pit
# 244                     Pine Ridge Pit        Russell Trest-Dirt Contractor
# 245             Stahr Portable Crusher            S J Stahr Dirt Movers Inc
# 246                         Molino Pit                     Sand & Dirt, Inc
# 247                        CENTURY PIT                  Sand and Dirt, Inc.
# 248             Sierra Rock & Dirt Inc             Sierra Rock & Dirt, Inc.
# 249            Simpson Sand and Gravel                 Simpson Dirtworx llc
# 250              Pettibone Jaw Crusher                 SIMPSON DIRTWORX LLC
# 251                      Chieftan 1400                 SIMPSON DIRTWORX LLC
# 252                           SLAY PIT                  Slay'S Dirt Hauling
# 253                 Southside Dirt Pit               Southside Dirt Company
# 254                   Mike's Money Pit           Spry's Dirt & Gravel, Inc.
# 255                        Stewart Pit                     Stewart Dirt Pit
# 256  Stewart Dirt Work Inc - Hanna Pit              Stewart Dirt Work, Inc.
# 257               Highway 642 Dirt Pit             Sweat'S Dirt Hauling Inc
# 258                 Toler Roe Dirt Pit                   Toler Roe Dirt Pit
# 259                   La Calichera Pit    Tres Palacios Dirt, Sand & Gravel
# 260                            Crusher                    Vogt Dirt Service
# 261                      ADDISON LEASE    Watson Dirt Sand & Gravel Pit Inc
# 262                           Y B Mine                      Y B Dirt & Loam
# 263              Yarbrough Dirt Pit #1               Yarbrough Dirt Pit Inc
#
#     State         Status      Type
# 0     OR         Active    Surface
# 1     CO      Abandoned    Surface
# 2     ND      Abandoned    Surface
# 3     UT      Abandoned   Facility
# 4     UT      Abandoned    Surface
# 5     ID      Abandoned    Surface
# 6     LA      Abandoned    Surface
# 7     TX      Abandoned    Surface
# 8     KS   Intermittent    Surface
# 9     ME      Abandoned    Surface
# 10    LA      Abandoned    Surface
# 11    AR      Abandoned    Surface
# 12    LA      Abandoned    Surface
# 13    OK      Abandoned    Surface
# 14    LA      Abandoned    Surface
# 15    OK      Abandoned    Surface
# 16    AR      Abandoned    Surface
# 17    LA      Abandoned    Surface
# 18    MS      Abandoned    Surface
# 19    NM      Abandoned    Surface
# 20    OK      Abandoned    Surface
# 21    IA      Abandoned    Surface
# 22    LA      Abandoned    Surface
# 23    OK      Abandoned    Surface
# 24    LA      Abandoned    Surface
# 25    WA      Abandoned    Surface
# 26    OK      Abandoned    Surface
# 27    OK      Abandoned    Surface
# 28    AK   Intermittent    Surface
# 29    WV      Abandoned    Surface
# ..    ...            ...       ...
# 234   KY      Abandoned    Surface
# 235   VA      Abandoned    Surface
# 236   TX      Abandoned    Surface
# 237   FL      Abandoned    Surface
# 238   AZ   Intermittent    Surface
# 239   AR      Abandoned    Surface
# 240   NM         Active    Surface
# 241   LA      Abandoned    Surface
# 242   TX      Abandoned    Surface
# 243   LA      Abandoned    Surface
# 244   TX      Abandoned    Surface
# 245   UT      Abandoned    Surface
# 246   FL         Active    Surface
# 247   FL      Abandoned    Surface
# 248   MT      Abandoned    Surface
# 249   VT      Abandoned    Surface
# 250   VT   Intermittent    Surface
# 251   VT   Intermittent    Surface
# 252   AL      Abandoned    Surface
# 253   LA      Abandoned    Surface
# 254   MO   Intermittent    Surface
# 255   TX      Abandoned    Surface
# 256   TX      Abandoned    Surface
# 257   SC      Abandoned    Surface
# 258   LA      Abandoned    Surface
# 259   TX      Abandoned    Surface
# 260   MN   Intermittent    Surface
# 261   LA      Abandoned    Surface
# 262   TX      Abandoned    Surface
# 263   TX      Abandoned    Surface
#
# [264 rows x 8 columns]
