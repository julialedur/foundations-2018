# %%
import pandas as pd

# %%
pd.read_csv("countries.csv")
# Out:
#                     Country   Continent  GDP_per_capita  life_expectancy  \
# 0               Afghanistan        Asia             663           54.863
# 1                   Albania      Europe            4195           74.200
# 2                   Algeria      Africa            5098           68.963
# 3                    Angola      Africa            2446           45.234
# 4       Antigua and Barbuda  N. America           12738           73.544
# 5                 Argentina  S. America           10571           73.822
# 6                   Armenia      Europe            2114           71.494
# 7                 Australia     Oceania           29241           79.930
# 8                   Austria      Europe           32008           78.330
# 9                Azerbaijan      Europe            2533           66.851
# 10                  Bahamas  N. America           22728           72.370
# 11                  Bahrain        Asia           22015           74.497
# ...

# %%
type(pd.read_csv("countries.csv"))
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("countries.csv") # df stands for dataframe. don't name two variables 'dataframe'

# %%
df.head() # to look at the first rows
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.tail() # to look at the last rows
# Out:
#                 Country Continent  GDP_per_capita  life_expectancy  Population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.tail(3) # to look at the 3 last rows
# Out:
#          Country Continent  GDP_per_capita  life_expectancy  Population
# 185  Yemen, Rep.      Asia            2217           60.404    17723186
# 186       Zambia    Africa            1035           41.802    10201562
# 187     Zimbabwe    Africa             745           43.976    12509477

# %%
df.shape # tells you how many rows and columns you have
# Out:
# (188, 5)

# %%
df.dtypes # tells you the type of stuff 
# object = string
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %% [markdown]
# # The three things you should do when you read in a data set

# %% [markdown]
# ### 1. Look at .head to see if the first rows look right

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %% [markdown]
# ### 2. Look at .shape to see how many rows and columns your data

# %%
df.shape
# Out:
# (188, 5)

# %% [markdown]
# ### 3. Look at .dtypes to see the data types of all of your columns and the name of your columns

# %%
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %% [markdown]
# # Let's do stuff with this dataset

# %%
df.sort_values(by="Population")
# Out:
#                               Country   Continent  GDP_per_capita  \
# 64                          Greenland  N. America           33204
# 4                 Antigua and Barbuda  N. America           12738
# 146                        Seychelles      Africa           15230
# 87                           Kiribati     Oceania            3501
# 169                             Tonga     Oceania            4886
# 65                            Grenada  N. America            8655
# 111             Micronesia, Fed. Sts.     Oceania            5530
# 140  Saint Vincent and the Grenadines  N. America            5893
# 142             Sao Tome and Principe      Africa            1320
# 139                       Saint Lucia  N. America            8676
# 141                             Samoa     Oceania            4090
# 181                           Vanuatu     Oceania            3762
# 16                             Belize  N. America            6545
# ...

# %%
#sort_values always sorts by ascending order (aka smallest first)
df.sort_values(by="Population", ascending=False).head(3)
# Out:
#            Country   Continent  GDP_per_capita  life_expectancy  Population
# 34           China        Asia            3407           72.124  1269116737
# 75           India        Asia            1648           62.129  1053898107
# 178  United States  N. America           39758           76.800   282496310

# %%
df['life_expectancy']
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
# 5      73.822
# 6      71.494
# 7      79.930
# 8      78.330
# 9      66.851
# 10     72.370
# 11     74.497
# 12     65.309
# 13     73.118
# 14     68.990
# 15     77.910
# 16     70.425
# 17     55.261
# 18     60.307
# 19     62.994
# 20     74.882
# 21     50.567
# 22     70.261
# 23     75.927
# 24     71.590
# 25     50.589
# 26     48.251
# 27     62.030
# 28     51.960
# 29     79.410
#         ...
# 158    67.851
# 159    48.689
# 160    79.840
# 161    79.990
# 162    73.316
# 163    76.020
# 164    63.570
# 165    50.010
# 166    70.921
# 167    59.468
# 168    53.585
# 169    70.810
# 170    68.533
# 171    73.159
# 172    70.010
# 173    63.925
# 174    48.126
# 175    67.790
# 176    74.163
# 177    78.040
# 178    76.800
# 179    74.777
# 180    66.999
# 181    67.438
# 182    72.432
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# ...

# %%
type(df['Continent']) 
#series are the things that look ugly. Every column is a series. 
# If you pull out a simple column, it's called a SERIES 
# A DATAFRAME is made up of many SERIES 
# dataframe = pretty 
# series = ugly
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## If you have

# %%
df['Continent'].value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %%
df.Continent #works too!
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
# 5      S. America
# 6          Europe
# 7         Oceania
# 8          Europe
# 9          Europe
# 10     N. America
# 11           Asia
# 12           Asia
# 13     N. America
# 14         Europe
# 15         Europe
# 16     N. America
# 17         Africa
# 18           Asia
# 19     S. America
# 20         Europe
# 21         Africa
# 22     S. America
# 23           Asia
# 24         Europe
# 25         Africa
# 26         Africa
# 27           Asia
# 28         Africa
# 29     N. America
#           ...
# 158    S. America
# 159        Africa
# 160        Europe
# 161        Europe
# 162          Asia
# 163          Asia
# 164          Asia
# 165        Africa
# 166          Asia
# 167          Asia
# 168        Africa
# 169       Oceania
# 170    N. America
# 171        Africa
# 172          Asia
# 173          Asia
# 174        Africa
# 175        Europe
# 176          Asia
# ...

# %% [markdown]
# ### You can do df['colname'] or df.colname, they're the same (at least for now)

# %%
df.life_expectancy.median()  # bound methods errors means you forgot the parentesis
# Out:
# 70.04150000000001

# %%
df.life_expectancy.mean()
# Out:
# 66.50153603526596

# %%
# Is the mean gdp higher or lower than the median GDP?

# %%
df.GDP_per_capita.mean()
# Out:
# 9977.558510638299

# %%
df.GDP_per_capita.median()
# Out:
# 5290.5

# %%
df.Population.sum()
# Out:
# 6115042358

# %%
df.life_expectancy.max()
# Out:
# 81.35

# %%
df.sort_values(by='life_expectancy', ascending=False).head(3)
# Out:
#               Country Continent  GDP_per_capita  life_expectancy  Population
# 83              Japan      Asia           28559           81.350   125720310
# 72   Hong Kong, China      Asia           29972           80.361     6783317
# 161       Switzerland    Europe           34386           79.990     7167908

# %%
df.sort_values? #gives you documentation so you don't have to Google it
# Out:
#   File "<ipython-input-27-dcdb9477b5b6>", line 1
#     df.sort_values? #gives you documentation so you don't have to Google it
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Why would we want to create a dataframe?

# %% [markdown]
# #### To pull up stuff from an API

# %%
df.life_expectancy.describe()
# or 
df['life_expectancy'].describe()

# %%
df.Population.describe()

# %%
df.describe() # to all columns that are numbers

# %%
df.life_expectancy.median()

# %% [markdown]
# ## Do analysis based on groups

# %%
# We could do either way: 

df.groupby('Continent').['life_expectancy'].median()
df.groupby('Continent').life_expectancy.median()

# %%
# The thing on the left is called the INDEX 
# The thing on the right is called the VALUES  

df.groupby('Continent').Population.sum()

# %%
# This is a SERIES, it only has an INDEX and VALUES 
# and it doesn't actually have columns to sort by 
# we sort this with .sort_values(), but since we don't have any, we don't 
# need to give it one 

df.groupby('Continent').Population.sum().sort_values(ascending=False)

# %%
df.Continent.value_counts(normalize=True)

# %%
df.Continent.value_counts(normalize=True) * 100

# %%
df.GDP_per_capita * df.Population

# %% [markdown]
# # Create a new column with df['colname'] = ...

# %%
# This doesn't work 
# df.GDP = df.GDP_per_capita * df.Population

df['GDP'] = df.GDP_per_capita * df.Population
df.head()

# %%
df['Continent'] == 'Africa'

# %%
africa_df = df[df.Continent == 'Africa'] # to find out what countries are in Africa 
africa_df.head()

# %%
# Multiple conditions 
# wrap each condition in parenthesis 

df[(df.Continent == 'Africa') & (df.life_expectancy > 60)]

# %%
# %matplotlib inline

# %%
df.groupby('Continent').life_expectancy.median().plot()

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
df.groupby("Continent").life_expectancy.median().plot()

# %%
df.groupby("Continent").life_expectancy.median().plot(kind='barh')

# %%
df.groupby("Continent").life_expectancy.median().sort_values().plot(kind='barh')

# %%
df.groupby("Continent").life_expectancy.median().sort_values(ascending=False).plot(kind='barh')

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.plot(x='GDP_per_capita', y='life_expectancy')

# %%
df.plot(x='GDP_per_capita', y='life_expectancy', kind='scatter')
